# %% [markdown]
# # Converters and advanced Data Structures

# %% [markdown]
# ## (Default) Converters and settings

# %%
import pandas as pd
import numpy as np
import xlwings as xw
import datetime as dt

# %%
wb = xw.Book()
wb
# Out:
# <Book [Book1]>

# %%
sheet = wb.sheets[0]
sheet
# Out:
# <Sheet [Book1]Sheet1>

# %%
sheet.range("A1").value = [[4.32, "Dog"], [dt.datetime(2020, 3, 30), None]]

# %%
sheet.range("A1:B2").value
# Out:
# [[4.32, 'Dog'], [datetime.datetime(2020, 3, 30, 0, 0), None]]

# %%
sheet.range("A1").expand().value
# Out:
# [[4.32, 'Dog'], [datetime.datetime(2020, 3, 30, 0, 0), None]]

# %%
sheet.range("A1").options(expand="table").value
# Out:
# [[4.32, 'Dog'], [datetime.datetime(2020, 3, 30, 0, 0), None]]

# %%
cells = sheet.range("A1:B2")

# %%
cells.options(transpose = True).value
# Out:
# [[4.32, datetime.datetime(2020, 3, 30, 0, 0)], ['Dog', None]]

# %%
cells.options(numbers = int).value
# Out:
# [[4, 'Dog'], [datetime.datetime(2020, 3, 30, 0, 0), None]]

# %%
cells.options(numbers = lambda x: round(x, 1)).value
# Out:
# [[4.3, 'Dog'], [datetime.datetime(2020, 3, 30, 0, 0), None]]

# %%
cells.options(empty = "No Data.").value
# Out:
# [[4.32, 'Dog'], [datetime.datetime(2020, 3, 30, 0, 0), 'No Data.']]

# %% [markdown]
# ## The Numpy Converter

# %%
my_array = np.random.normal(10, 2, (3, 4))
my_array
# Out:
# array([[ 8.91296136, 11.39421011,  8.14733269,  9.36196139],
#        [12.56712631, 11.27712263,  9.65623853, 11.80921047],
#        [11.93958946,  7.79905797, 11.46075219,  5.93820417]])

# %%
sheet.range("A5").value = my_array

# %%
sheet.range("A5").options(expand = "table").value # nested list
# Out:
# [[8.91296136446503, 11.394210114149944, 8.147332693853013, 9.361961386434606],
#  [12.567126309349987, 11.27712262959545, 9.656238531477014, 11.80921046547566],
#  [11.939589455394511,
#   7.799057966929558,
#   11.460752194147242,
#   5.938204170664607]]

# %%
sheet.range("A5").options(convert = np.array, 
                          expand = "table").value # np.array
# Out:
# array([[ 8.91296136, 11.39421011,  8.14733269,  9.36196139],
#        [12.56712631, 11.27712263,  9.65623853, 11.80921047],
#        [11.93958946,  7.79905797, 11.46075219,  5.93820417]])

# %%
sheet.range("A5").options(np.array, expand = "table", 
                          transpose = True, numbers = int).value
# Out:
# array([[ 9, 13, 12],
#        [11, 11,  8],
#        [ 8, 10, 11],
#        [ 9, 12,  6]])

# %% [markdown]
# ## The Dictionary Converter

# %%
sheet.range("A9").value = [["a", 1], ["b", 2], ["c", 3]]

# %%
sheet.range("A9").options(expand = "table").value # nested list
# Out:
# [['a', 1.0], ['b', 2.0], ['c', 3.0]]

# %%
sheet.range("A9").options(dict, expand = "table").value # dictionary
# Out:
# {'a': 1.0, 'b': 2.0, 'c': 3.0}

# %%
my_dic = sheet.range("A9").options(dict, expand = "table", 
                                   numbers = int).value
my_dic
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
type(my_dic)
# Out:
# dict

# %%
my_dic2 = {"d":4, "e":5, "f":6}
my_dic2
# Out:
# {'d': 4, 'e': 5, 'f': 6}

# %%
sheet.range("A13").value = my_dic2

# %%
sheet.range("A13").options(transpose = True).value = my_dic2

# %%
sheet.range("A5:B7").options(dict).value
# Out:
# {8.91296136446503: 11.394210114149944,
#  12.567126309349987: 11.27712262959545,
#  11.939589455394511: 7.799057966929558}

# %% [markdown]
# ## The Pandas DataFrame Converter (Part 1)

# %%
import pandas as pd
import xlwings as xw

# %%
df = pd.read_csv("summer.csv")

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
wb = xw.Book()

# %%
sheet = wb.sheets[0]

# %%
sheet["A1"].value = df

# %%
sheet["A1"].options(pd.DataFrame, expand = "table", numbers = int).value
# Out:
#         City      Sport           Discipline                    Athlete  \
# Year
# 1896  Athens   Aquatics             Swimming              HAJOS, Alfred
# 1896  Athens   Aquatics             Swimming           HERSCHMANN, Otto
# 1896  Athens   Aquatics             Swimming          DRIVAS, Dimitrios
# 1896  Athens   Aquatics             Swimming         MALOKINIS, Ioannis
# 1896  Athens   Aquatics             Swimming         CHASAPIS, Spiridon
# ...      ...        ...                  ...                        ...
# 2012  London  Wrestling  Wrestling Freestyle         JANIKOWSKI, Damian
# 2012  London  Wrestling  Wrestling Freestyle  REZAEI, Ghasem Gholamreza
# 2012  London  Wrestling  Wrestling Freestyle             TOTROV, Rustam
# 2012  London  Wrestling  Wrestling Freestyle          ALEKSANYAN, Artur
# 2012  London  Wrestling  Wrestling Freestyle             LIDBERG, Jimmy
#
#      Country Gender                       Event   Medal
# Year
# 1896     HUN    Men              100M Freestyle    Gold
# 1896     AUT    Men              100M Freestyle  Silver
# 1896     GRE    Men  100M Freestyle For Sailors  Bronze
# 1896     GRE    Men  100M Freestyle For Sailors    Gold
# 1896     GRE    Men  100M Freestyle For Sailors  Silver
# ...      ...    ...                         ...     ...
# 2012     POL    Men                    Wg 84 KG  Bronze
# 2012     IRI    Men                    Wg 96 KG    Gold
# 2012     RUS    Men                    Wg 96 KG  Silver
# 2012     ARM    Men                    Wg 96 KG  Bronze
# 2012     SWE    Men                    Wg 96 KG  Bronze
#
# [31165 rows x 8 columns]

# %%
sheet["B1"].options(pd.DataFrame, expand = "table", index = False).value
# Out:
#          Year    City      Sport           Discipline  \
# 0      1896.0  Athens   Aquatics             Swimming
# 1      1896.0  Athens   Aquatics             Swimming
# 2      1896.0  Athens   Aquatics             Swimming
# 3      1896.0  Athens   Aquatics             Swimming
# 4      1896.0  Athens   Aquatics             Swimming
# ...       ...     ...        ...                  ...
# 31160  2012.0  London  Wrestling  Wrestling Freestyle
# 31161  2012.0  London  Wrestling  Wrestling Freestyle
# 31162  2012.0  London  Wrestling  Wrestling Freestyle
# 31163  2012.0  London  Wrestling  Wrestling Freestyle
# 31164  2012.0  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
sheet["A1"].options(pd.DataFrame, expand = "table", index = False).value
# Out:
#          Year    City      Sport           Discipline  \
# 0      1896.0  Athens   Aquatics             Swimming
# 1      1896.0  Athens   Aquatics             Swimming
# 2      1896.0  Athens   Aquatics             Swimming
# 3      1896.0  Athens   Aquatics             Swimming
# 4      1896.0  Athens   Aquatics             Swimming
# ...       ...     ...        ...                  ...
# 31160  2012.0  London  Wrestling  Wrestling Freestyle
# 31161  2012.0  London  Wrestling  Wrestling Freestyle
# 31162  2012.0  London  Wrestling  Wrestling Freestyle
# 31163  2012.0  London  Wrestling  Wrestling Freestyle
# 31164  2012.0  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
sheet["A1"].options(pd.DataFrame, expand = "table",
                    index = False, header = False).value
# Out:
#             0       1          2                    3  \
# 0      1896.0  Athens   Aquatics             Swimming
# 1      1896.0  Athens   Aquatics             Swimming
# 2      1896.0  Athens   Aquatics             Swimming
# 3      1896.0  Athens   Aquatics             Swimming
# 4      1896.0  Athens   Aquatics             Swimming
# ...       ...     ...        ...                  ...
# 31160  2012.0  London  Wrestling  Wrestling Freestyle
# 31161  2012.0  London  Wrestling  Wrestling Freestyle
# 31162  2012.0  London  Wrestling  Wrestling Freestyle
# 31163  2012.0  London  Wrestling  Wrestling Freestyle
# 31164  2012.0  London  Wrestling  Wrestling Freestyle
#
#                                4    5    6                           7       8
# 0                  HAJOS, Alfred  HUN  Men              100M Freestyle    Gold
# 1               HERSCHMANN, Otto  AUT  Men              100M Freestyle  Silver
# 2              DRIVAS, Dimitrios  GRE  Men  100M Freestyle For Sailors  Bronze
# 3             MALOKINIS, Ioannis  GRE  Men  100M Freestyle For Sailors    Gold
# 4             CHASAPIS, Spiridon  GRE  Men  100M Freestyle For Sailors  Silver
# ...                          ...  ...  ...                         ...     ...
# 31160         JANIKOWSKI, Damian  POL  Men                    Wg 84 KG  Bronze
# 31161  REZAEI, Ghasem Gholamreza  IRI  Men                    Wg 96 KG    Gold
# 31162             TOTROV, Rustam  RUS  Men                    Wg 96 KG  Silver
# 31163          ALEKSANYAN, Artur  ARM  Men                    Wg 96 KG  Bronze
# 31164             LIDBERG, Jimmy  SWE  Men                    Wg 96 KG  Bronze
#
# [31165 rows x 9 columns]

# %%
df = sheet["A1"].options(pd.DataFrame, expand = "table", 
                         index = False, header = False).value
df|

# %%
df.columns = ["Year", "City", "Sport", "Discipline", "Athlete",
              "Country", "Gender", "Event", "Medal"]

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
wb.close()

# %% [markdown]
# ## The Pandas DataFrame Converter (Part 2)

# %%
wb = xw.Book()

# %%
sheet = wb.sheets[0]

# %%
df = pd.read_csv("summer.csv")
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
sheet["A1"].options(index = False).value = df

# %%
sheet["A1"].options(pd.DataFrame, expand = "table", index = False).value
# Out:
#          Year    City      Sport           Discipline  \
# 0      1896.0  Athens   Aquatics             Swimming
# 1      1896.0  Athens   Aquatics             Swimming
# 2      1896.0  Athens   Aquatics             Swimming
# 3      1896.0  Athens   Aquatics             Swimming
# 4      1896.0  Athens   Aquatics             Swimming
# ...       ...     ...        ...                  ...
# 31160  2012.0  London  Wrestling  Wrestling Freestyle
# 31161  2012.0  London  Wrestling  Wrestling Freestyle
# 31162  2012.0  London  Wrestling  Wrestling Freestyle
# 31163  2012.0  London  Wrestling  Wrestling Freestyle
# 31164  2012.0  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
sheet["A1"].expand().clear_contents()

# %%
sheet["A1"].options(index = False, header = False).value = df

# %% [markdown]
# __Excursus: Autofit__

# %%
sheet["E1"].autofit() #autofit single cells

# %%
sheet["D1:E10"].columns.autofit() #autofit columns in range object

# %%
sheet["A:I"].autofit() #autofit full columns

# %% [markdown]
# ## Data Science Application: Inspect and Manipulate DataFrames in Excel

# %%
import pandas as pd
import xlwings as xw

# %%
df = pd.read_csv("summer.csv")

# %%
df
# Out:
#        Year    City      Sport                    Athlete Country Gender  \
# 0      1896  Athens   Aquatics              HAJOS, Alfred     HUN    Men
# 1      1896  Athens   Aquatics           HERSCHMANN, Otto     AUT    Men
# 2      1896  Athens   Aquatics          DRIVAS, Dimitrios     GRE    Men
# 3      1896  Athens   Aquatics         MALOKINIS, Ioannis     GRE    Men
# 4      1896  Athens   Aquatics         CHASAPIS, Spiridon     GRE    Men
# ...     ...     ...        ...                        ...     ...    ...
# 31160  2012  London  Wrestling         JANIKOWSKI, Damian     POL    Men
# 31161  2012  London  Wrestling  REZAEI, Ghasem Gholamreza     IRI    Men
# 31162  2012  London  Wrestling             TOTROV, Rustam     RUS    Men
# 31163  2012  London  Wrestling          ALEKSANYAN, Artur     ARM    Men
# 31164  2012  London  Wrestling             LIDBERG, Jimmy     SWE    Men
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 7 columns]

# %%
# drop columns
df.drop(columns = ["Discipline", "Event"], inplace = True)

# %%
# reorder columns
df = df.reindex(columns = ["Athlete", "Medal", "Year", "City",
                      "Sport", "Country", "Gender"])

# %%
# rename columns
df.rename(columns = {"Athlete":"Name", "City":"Host_City",
                     "Country":"Nationality"}, inplace = True)

# %%
df
# Out:
#                             Name   Medal  Year Host_City      Sport  \
# 0                  HAJOS, Alfred    Gold  1896    Athens   Aquatics
# 1               HERSCHMANN, Otto  Silver  1896    Athens   Aquatics
# 2              DRIVAS, Dimitrios  Bronze  1896    Athens   Aquatics
# 3             MALOKINIS, Ioannis    Gold  1896    Athens   Aquatics
# 4             CHASAPIS, Spiridon  Silver  1896    Athens   Aquatics
# ...                          ...     ...   ...       ...        ...
# 31160         JANIKOWSKI, Damian  Bronze  2012    London  Wrestling
# 31161  REZAEI, Ghasem Gholamreza    Gold  2012    London  Wrestling
# 31162             TOTROV, Rustam  Silver  2012    London  Wrestling
# 31163          ALEKSANYAN, Artur  Bronze  2012    London  Wrestling
# 31164             LIDBERG, Jimmy  Bronze  2012    London  Wrestling
#
#       Nationality Gender
# 0             HUN    Men
# 1             AUT    Men
# 2             GRE    Men
# 3             GRE    Men
# 4             GRE    Men
# ...           ...    ...
# 31160         POL    Men
# 31161         IRI    Men
# 31162         RUS    Men
# 31163         ARM    Men
# 31164         SWE    Men
#
# [31165 rows x 7 columns]

# %%
df = pd.read_csv("summer.csv")
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
wb = xw.Book()
sheet = wb.sheets[0]
sheet["A1"].options(index = False).value = df

# %%
sheet["A1"].options(pd.DataFrame, expand = "table", index = False).value
# Out:
#          Year    City      Sport           Discipline  \
# 0      1896.0  Athens   Aquatics             Swimming
# 1      1896.0  Athens   Aquatics             Swimming
# 2      1896.0  Athens   Aquatics             Swimming
# 3      1896.0  Athens   Aquatics             Swimming
# 4      1896.0  Athens   Aquatics             Swimming
# ...       ...     ...        ...                  ...
# 31160  2012.0  London  Wrestling  Wrestling Freestyle
# 31161  2012.0  London  Wrestling  Wrestling Freestyle
# 31162  2012.0  London  Wrestling  Wrestling Freestyle
# 31163  2012.0  London  Wrestling  Wrestling Freestyle
# 31164  2012.0  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %% [markdown]
# ## The Pandas Series Converter

# %%
import pandas as pd
import xlwings as xw

# %%
df = pd.read_csv("summer.csv")
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
athlete = df.Athlete
athlete
# Out:
# 0                    HAJOS, Alfred
# 1                 HERSCHMANN, Otto
# 2                DRIVAS, Dimitrios
# 3               MALOKINIS, Ioannis
# 4               CHASAPIS, Spiridon
#                    ...
# 31160           JANIKOWSKI, Damian
# 31161    REZAEI, Ghasem Gholamreza
# 31162               TOTROV, Rustam
# 31163            ALEKSANYAN, Artur
# 31164               LIDBERG, Jimmy
# Name: Athlete, Length: 31165, dtype: object

# %%
wb = xw.Book()

# %%
sheet = wb.sheets[0]

# %%
sheet["A1"].value = athlete

# %%
sheet["B1"].options(pd.Series, expand = "table", index = False).value
# Out:
# 0                    HAJOS, Alfred
# 1                 HERSCHMANN, Otto
# 2                DRIVAS, Dimitrios
# 3               MALOKINIS, Ioannis
# 4               CHASAPIS, Spiridon
#                    ...
# 31160           JANIKOWSKI, Damian
# 31161    REZAEI, Ghasem Gholamreza
# 31162               TOTROV, Rustam
# 31163            ALEKSANYAN, Artur
# 31164               LIDBERG, Jimmy
# Name: Athlete, Length: 31165, dtype: object

# %%
sheet["A1"].expand().clear_contents()

# %%
sheet["A1"].options(index = False).value = athlete

# %%
sheet["A1"].options(pd.Series, expand = "table", index = False).value
# Out:
# 0                    HAJOS, Alfred
# 1                 HERSCHMANN, Otto
# 2                DRIVAS, Dimitrios
# 3               MALOKINIS, Ioannis
# 4               CHASAPIS, Spiridon
#                    ...
# 31160           JANIKOWSKI, Damian
# 31161    REZAEI, Ghasem Gholamreza
# 31162               TOTROV, Rustam
# 31163            ALEKSANYAN, Artur
# 31164               LIDBERG, Jimmy
# Name: Athlete, Length: 31165, dtype: object

# %%
sheet["A1"].expand().clear_contents()

# %%
df = pd.read_csv("summer.csv", index_col = "Athlete")
df
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# HAJOS, Alfred                 HUN    Men              100M Freestyle    Gold
# HERSCHMANN, Otto              AUT    Men              100M Freestyle  Silver
# DRIVAS, Dimitrios             GRE    Men  100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis            GRE    Men  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon            GRE    Men  100M Freestyle For Sailors  Silver
# ...                           ...    ...                         ...     ...
# JANIKOWSKI, Damian            POL    Men                    Wg 84 KG  Bronze
# REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG    Gold
# TOTROV, Rustam                RUS    Men                    Wg 96 KG  Silver
# ALEKSANYAN, Artur             ARM    Men                    Wg 96 KG  Bronze
# LIDBERG, Jimmy                SWE    Men                    Wg 96 KG  Bronze
#
# [31165 rows x 8 columns]

# %%
medal = df.Medal
medal
# Out:
# Athlete
# HAJOS, Alfred                  Gold
# HERSCHMANN, Otto             Silver
# DRIVAS, Dimitrios            Bronze
# MALOKINIS, Ioannis             Gold
# CHASAPIS, Spiridon           Silver
#                               ...
# JANIKOWSKI, Damian           Bronze
# REZAEI, Ghasem Gholamreza      Gold
# TOTROV, Rustam               Silver
# ALEKSANYAN, Artur            Bronze
# LIDBERG, Jimmy               Bronze
# Name: Medal, Length: 31165, dtype: object

# %%
sheet["A1"].value = medal

# %%
sheet["A1"].options(pd.Series, expand = "table").value
# Out:
# Athlete
# HAJOS, Alfred                  Gold
# HERSCHMANN, Otto             Silver
# DRIVAS, Dimitrios            Bronze
# MALOKINIS, Ioannis             Gold
# CHASAPIS, Spiridon           Silver
#                               ...
# JANIKOWSKI, Damian           Bronze
# REZAEI, Ghasem Gholamreza      Gold
# TOTROV, Rustam               Silver
# ALEKSANYAN, Artur            Bronze
# LIDBERG, Jimmy               Bronze
# Name: Medal, Length: 31165, dtype: object

# %%
sheet["A1"].options(pd.Series, expand = "table", header = False).value
# Out:
# Athlete                       Medal
# HAJOS, Alfred                  Gold
# HERSCHMANN, Otto             Silver
# DRIVAS, Dimitrios            Bronze
# MALOKINIS, Ioannis             Gold
#                               ...
# JANIKOWSKI, Damian           Bronze
# REZAEI, Ghasem Gholamreza      Gold
# TOTROV, Rustam               Silver
# ALEKSANYAN, Artur            Bronze
# LIDBERG, Jimmy               Bronze
# Length: 31166, dtype: object
